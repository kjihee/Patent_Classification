# %%
from network2vec import network2vec

# %%
from importlib import reload
import network2vec
reload(network2vec)
from network2vec import network2vec

# %%
import pandas as pd

# %%
df=pd.read_csv("ipc_9.csv")

# %%
abstract_pickle = pd.read_pickle("../../../../kimjihee/다운로드/abstract (1).pkl")
labels = abstract_pickle["label"]

# %%
df.loc[100]
# Out:
# 0                 24
# H04B7185    H04J1100
# Name: 100, dtype: object

# %%
net2vec = network2vec(labels=labels,
                    model='word2vec', filename='ipc_9.csv',
                    class_name='ipc', previous_model=None, is_network=False)

# %%
X = net2vec.train_word2vec()
# Out:
# {'52,H04W7404': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb54908>, '57': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb54940>, '725,B28B722': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb54978>, '2,H04B706': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb549b0>, '316,G09G502': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb549e8>, '99,H04J1100': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb54a20>, '753,A61B51455': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb54a58>, '618,H04L2908': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb54a90>, '249': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb54ac8>, '232,H04R2500': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb54b00>, '29,H04L2720': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb54b38>, '625': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb54b70>, '153,H04B118': <gensim.models.keyedvectors.Vocab object at 0x7f8cecb54ba8>, '21,H04L2502': <gensim.models.ke
# ...
